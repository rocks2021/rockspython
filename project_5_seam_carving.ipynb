# %% [markdown]
# <a href="https://colab.research.google.com/github/rocks2021/rockspython/blob/main/project_5_seam_carving.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import cv2
import numpy as np
from numba import jit
from tqdm import trange

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
d = mpimg.imread('/content/drive/My Drive/d.png')
plt.imshow(d)

# %%
cv2.imwrite('d.jpg', d, [int(cv2.IMWRITE_JPEG_QUALITY), 100])
# Out:
# True

# %%
img = mpimg.imread('/content/drive/My Drive/d.jpg')
plt.imshow(img)

# %%
def display_map(img):
    grayscale_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    grayscale_img = cv2.GaussianBlur(grayscale_img,(7,7),0)

    laplacian = cv2.Laplacian(grayscale_img,cv2.CV_64F)
    abs_laplacian = cv2.convertScaleAbs(laplacian)
    imageMap = abs_laplacian

    plt.subplot(1,2,1),plt.imshow(img,cmap = 'gray')
    plt.title('Original'), plt.xticks([]), plt.yticks([])
    plt.subplot(1,2,2),plt.imshow(abs_laplacian,cmap = 'gray')
    plt.title('Laplacian'), plt.xticks([]), plt.yticks([])   
    plt.show()

# %%
display_map(img)

# %%
@jit
def get_map(img):
    grayscale_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    grayscale_img = cv2.GaussianBlur(grayscale_img,(7,7),0)   
    laplacian = cv2.Laplacian(grayscale_img,cv2.CV_64F)
    abs_laplacian = cv2.convertScaleAbs(laplacian)
    imageMap = abs_laplacian   
    return imageMap

# %%
@jit
def min_seam(imageMap):    
    h,w = imageMap.shape[:2]   
    backtrack = np.zeros_like(imageMap, dtype=np.int)
    
    for i in range(1,h):
        for j in range(0,w):
            if j == 0:
                idx = np.argmin(imageMap[i - 1, j:j + 2])
                backtrack[i, j] = idx + j
                min_energy = imageMap[i - 1, idx + j]
            else:
                idx = np.argmin(imageMap[i - 1, j - 1:j + 2])
                backtrack[i, j] = idx + j - 1
                min_energy = imageMap[i - 1, idx + j - 1]

            imageMap[i, j] += min_energy

    return imageMap, backtrack

# %%
@jit
def carve_seam(image):
    h,w = image.shape[:2]    
    costMap,backtrack = min_seam(get_map(image))   
    deletionMask = np.ones((h,w), dtype=np.bool)
    
    j = np.argmin(costMap[-1])   
    for i in reversed(range(h)):
        deletionMask[i,j] = False
        j = backtrack[i,j]
    
    deletionMask = np.stack([deletionMask]*3,axis=2)   
    image = image[deletionMask].reshape((h,w-1,3))   
    return image

# %%
@jit
def crop_c(img, scale_c):
    r, c, _ = img.shape
    new_c = int(scale_c * c)

    for i in trange(c - new_c):
        img = carve_seam(img)

    return img

# %%
im_1 = crop_c(img, 0.6)
plt.imshow(im_1)
# Out:
# <ipython-input-11-2356ed5a0cb7>:1: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "crop_c" failed type inference due to: Untyped global name 'trange': cannot determine Numba type of <class 'function'>
#
# File "<ipython-input-11-2356ed5a0cb7>", line 6:
# def crop_c(img, scale_c):
#     <source elided>
#
#     for i in trange(c - new_c):
#     ^
#
#   @jit
# <ipython-input-11-2356ed5a0cb7>:1: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "crop_c" failed type inference due to: cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "<ipython-input-11-2356ed5a0cb7>", line 6:
# def crop_c(img, scale_c):
#     <source elided>
#
#     for i in trange(c - new_c):
#     ^
#
#   @jit
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:178: NumbaWarning: Function "crop_c" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "<ipython-input-11-2356ed5a0cb7>", line 3:
# def crop_c(img, scale_c):
#     r, c, _ = img.shape
#     ^
#
#   state.func_ir.loc))
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:188: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-11-2356ed5a0cb7>", line 3:
# def crop_c(img, scale_c):
#     r, c, _ = img.shape
#     ^
#
#   state.func_ir.loc))
# <ipython-input-11-2356ed5a0cb7>:1: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "crop_c" failed type inference due to: Untyped global name 'trange': cannot determine Numba type of <class 'function'>
#
# File "<ipython-input-11-2356ed5a0cb7>", line 6:
# def crop_c(img, scale_c):
#     <source elided>
#
#     for i in trange(c - new_c):
#     ^
#
#   @jit
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:178: NumbaWarning: Function "crop_c" was compiled in object mode without forceobj=True.
#
# File "<ipython-input-11-2356ed5a0cb7>", line 6:
# def crop_c(img, scale_c):
#     <source elided>
#
#     for i in trange(c - new_c):
#     ^
#
#   state.func_ir.loc))
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:188: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-11-2356ed5a0cb7>", line 6:
# def crop_c(img, scale_c):
#     <source elided>
#
#     for i in trange(c - new_c):
#     ^
#
#   state.func_ir.loc))
#   0%|          | 0/200 [00:00<?, ?it/s]<ipython-input-10-f895043930bf>:1: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "carve_seam" failed type inference due to: Untyped global name 'reversed': cannot determine Numba type of <class 'type'>
#
# File "<ipython-input-10-f895043930bf>", line 8:
# def carve_seam(image):
#     <source elided>
#     j = np.argmin(costMap[-1])
#     for i in reversed(range(h)):
#     ^
#
#   @jit
# <ipython-input-10-f895043930bf>:1: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "carve_seam" failed type inference due to: cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "<ipython-input-10-f895043930bf>", line 8:
# def carve_seam(image):
#     <source elided>
#     j = np.argmin(costMap[-1])
#     for i in reversed(range(h)):
#     ^
#
#   @jit
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:178: NumbaWarning: Function "carve_seam" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "<ipython-input-10-f895043930bf>", line 3:
# def carve_seam(image):
#     h,w = image.shape[:2]
#     ^
#
#   state.func_ir.loc))
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:188: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-10-f895043930bf>", line 3:
# def carve_seam(image):
#     h,w = image.shape[:2]
#     ^
#
#   state.func_ir.loc))
# <ipython-input-8-9755ae5f5bf9>:1: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "get_map" failed type inference due to: Unknown attribute 'cvtColor' of type Module(<module 'cv2.cv2' from '/usr/local/lib/python3.6/dist-packages/cv2/cv2.cpython-36m-x86_64-linux-gnu.so'>)
#
# File "<ipython-input-8-9755ae5f5bf9>", line 3:
# def get_map(img):
#     grayscale_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     ^
#
# During: typing of get attribute at <ipython-input-8-9755ae5f5bf9> (3)
#
# File "<ipython-input-8-9755ae5f5bf9>", line 3:
# def get_map(img):
#     grayscale_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     ^
#
#   @jit
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:178: NumbaWarning: Function "get_map" was compiled in object mode without forceobj=True.
#
# File "<ipython-input-8-9755ae5f5bf9>", line 2:
# @jit
# def get_map(img):
# ^
#
#   state.func_ir.loc))
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:188: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-8-9755ae5f5bf9>", line 2:
# @jit
# def get_map(img):
# ^
#
#   state.func_ir.loc))
# <ipython-input-9-d7b6371d15d9>:1: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "min_seam" failed type inference due to: No implementation of function Function(<function zeros_like at 0x7f57f0cd01e0>) found for signature:
#
#  >>> zeros_like(array(uint8, 2d, C), dtype=Function(<class 'int'>))
#
# There are 2 candidate implementations:
#   - Of which 2 did not match due to:
#   Overload of function 'zeros_like': File: numba/core/typing/npydecl.py: Line 525.
#     With argument(s): '(array(uint8, 2d, C), dtype=Function(<class 'int'>))':
#    No match.
#
# During: resolving callee type: Function(<function zeros_like at 0x7f57f0cd01e0>)
# During: typing of call at <ipython-input-9-d7b6371d15d9> (4)
#
#
# File "<ipython-input-9-d7b6371d15d9>", line 4:
# def min_seam(imageMap):
#     <source elided>
#     h,w = imageMap.shape[:2]
#     backtrack = np.zeros_like(imageMap, dtype=np.int)
#     ^
#
#   @jit
# <ipython-input-9-d7b6371d15d9>:1: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "min_seam" failed type inference due to: cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "<ipython-input-9-d7b6371d15d9>", line 6:
# def min_seam(imageMap):
#     <source elided>
#
#     for i in range(1,h):
#     ^
#
#   @jit
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:178: NumbaWarning: Function "min_seam" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "<ipython-input-9-d7b6371d15d9>", line 3:
# def min_seam(imageMap):
#     h,w = imageMap.shape[:2]
#     ^
#
#   state.func_ir.loc))
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:188: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-9-d7b6371d15d9>", line 3:
# def min_seam(imageMap):
#     h,w = imageMap.shape[:2]
#     ^
#
#   state.func_ir.loc))
# <ipython-input-10-f895043930bf>:1: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "carve_seam" failed type inference due to: Untyped global name 'reversed': cannot determine Numba type of <class 'type'>
#
# File "<ipython-input-10-f895043930bf>", line 8:
# def carve_seam(image):
#     <source elided>
#     j = np.argmin(costMap[-1])
#     for i in reversed(range(h)):
#     ^
#
#   @jit
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:178: NumbaWarning: Function "carve_seam" was compiled in object mode without forceobj=True.
#
# File "<ipython-input-10-f895043930bf>", line 8:
# def carve_seam(image):
#     <source elided>
#     j = np.argmin(costMap[-1])
#     for i in reversed(range(h)):
#     ^
#
#   state.func_ir.loc))
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:188: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-10-f895043930bf>", line 8:
# def carve_seam(image):
#     <source elided>
#     j = np.argmin(costMap[-1])
#     for i in reversed(range(h)):
#     ^
#
#   state.func_ir.loc))
#   0%|          | 1/200 [00:01<05:45,  1.74s/it]<ipython-input-10-f895043930bf>:1: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "carve_seam" failed type inference due to: Untyped global name 'reversed': cannot determine Numba type of <class 'type'>
#
# File "<ipython-input-10-f895043930bf>", line 8:
# def carve_seam(image):
#     <source elided>
#     j = np.argmin(costMap[-1])
#     for i in reversed(range(h)):
#     ^
#
#   @jit
# <ipython-input-10-f895043930bf>:1: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "carve_seam" failed type inference due to: cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "<ipython-input-10-f895043930bf>", line 8:
# def carve_seam(image):
#     <source elided>
#     j = np.argmin(costMap[-1])
#     for i in reversed(range(h)):
#     ^
#
#   @jit
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:178: NumbaWarning: Function "carve_seam" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "<ipython-input-10-f895043930bf>", line 3:
# def carve_seam(image):
#     h,w = image.shape[:2]
#     ^
#
#   state.func_ir.loc))
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:188: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-10-f895043930bf>", line 3:
# def carve_seam(image):
#     h,w = image.shape[:2]
#     ^
#
#   state.func_ir.loc))
# <ipython-input-8-9755ae5f5bf9>:1: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "get_map" failed type inference due to: Unknown attribute 'cvtColor' of type Module(<module 'cv2.cv2' from '/usr/local/lib/python3.6/dist-packages/cv2/cv2.cpython-36m-x86_64-linux-gnu.so'>)
#
# File "<ipython-input-8-9755ae5f5bf9>", line 3:
# def get_map(img):
#     grayscale_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     ^
#
# During: typing of get attribute at <ipython-input-8-9755ae5f5bf9> (3)
#
# File "<ipython-input-8-9755ae5f5bf9>", line 3:
# def get_map(img):
#     grayscale_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     ^
#
#   @jit
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:178: NumbaWarning: Function "get_map" was compiled in object mode without forceobj=True.
#
# File "<ipython-input-8-9755ae5f5bf9>", line 2:
# @jit
# def get_map(img):
# ^
#
#   state.func_ir.loc))
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:188: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-8-9755ae5f5bf9>", line 2:
# @jit
# def get_map(img):
# ^
#
#   state.func_ir.loc))
# <ipython-input-10-f895043930bf>:1: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "carve_seam" failed type inference due to: Untyped global name 'reversed': cannot determine Numba type of <class 'type'>
#
# File "<ipython-input-10-f895043930bf>", line 8:
# def carve_seam(image):
#     <source elided>
#     j = np.argmin(costMap[-1])
#     for i in reversed(range(h)):
#     ^
#
#   @jit
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:178: NumbaWarning: Function "carve_seam" was compiled in object mode without forceobj=True.
#
# File "<ipython-input-10-f895043930bf>", line 8:
# def carve_seam(image):
#     <source elided>
#     j = np.argmin(costMap[-1])
#     for i in reversed(range(h)):
#     ^
#
#   state.func_ir.loc))
# /usr/local/lib/python3.6/dist-packages/numba/core/object_mode_passes.py:188: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-10-f895043930bf>", line 8:
# def carve_seam(image):
#     <source elided>
#     j = np.argmin(costMap[-1])
#     for i in reversed(range(h)):
#     ^
#
#   state.func_ir.loc))
# 100%|██████████| 200/200 [00:05<00:00, 35.10it/s]
